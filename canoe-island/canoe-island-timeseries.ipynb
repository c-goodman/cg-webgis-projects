# %%
import ee
import geemap
import os
# geemap.update_package()

# %%
Map = geemap.Map()
Map
# Out:
# Map(center=[40, -100], controls=(WidgetControl(options=['position'], widget=HBox(children=(ToggleButton(value=…
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# ~\anaconda3\envs\gee\lib\site-packages\ee\data.py in _execute_cloud_call(call, num_retries)
#     333   try:
# --> 334     return call.execute(num_retries=num_retries)
#     335   except googleapiclient.errors.HttpError as e:
#
# ~\anaconda3\envs\gee\lib\site-packages\googleapiclient\_helpers.py in positional_wrapper(*args, **kwargs)
#     133                     logger.warning(message)
# --> 134             return wrapped(*args, **kwargs)
#     135
#
# ~\anaconda3\envs\gee\lib\site-packages\googleapiclient\http.py in execute(self, http, num_retries)
#     914         if resp.status >= 300:
# --> 915             raise HttpError(resp, content, uri=self.uri)
#     916         return self.postproc(resp, content)
#
# ...

# %%
feature = Map.draw_last_feature
roi = feature.geometry()

# %%
out_dir = os.path.join(os.path.expanduser('~'), 'Downloads')
# filename = os.path.join(out_dir, 'canoe-island-timelapse.tif')

# %%
geemap.ee_export_image(image, filename=filename, scale=100, region=roi, file_per_band=False)

# %%
# loc = ee.Geometry.Point(-97.2474, 30.0121)
collection = ee.ImageCollection('USDA/NAIP/DOQQ') \
    .filterBounds(roi) \
    .filterDate('2003-01-01', '2021-12-01') \
    .filter(ee.Filter.listContains("system:band_names", "N"))

# %%
geemap.ee_export_image_collection(collection, out_dir=out_dir, scale=5, region=roi, file_per_band=False)
# Out:
# Total number of images: 46
#
# Exporting 1/46: c_3009627_ne_14_2_20060614.tif
# Generating URL ...
# ...
# Please wait ...
# Data downloaded to C:\Users\Cooper\Downloads\c_3009627_ne_14_2_20060614.tif
#
#
# Exporting 2/46: c_3009627_nw_14_2_20060614.tif
# Generating URL ...
# ...
# Please wait ...
# Data downloaded to C:\Users\Cooper\Downloads\c_3009627_nw_14_2_20060614.tif
#
#
# Exporting 3/46: c_3009627_se_14_2_20060614.tif
# Generating URL ...
# ...
# Please wait ...
# Data downloaded to C:\Users\Cooper\Downloads\c_3009627_se_14_2_20060614.tif
#
#
# Exporting 4/46: c_3009627_sw_14_2_20060614.tif
# Generating URL ...
# ...
# Please wait ...
# Data downloaded to C:\Users\Cooper\Downloads\c_3009627_sw_14_2_20060614.tif
#
#
# Exporting 5/46: c_3009635_ne_14_2_20060614.tif
# Generating URL ...
# ...
# Please wait ...
# Data downloaded to C:\Users\Cooper\Downloads\c_3009635_ne_14_2_20060614.tif
#
#
# Exporting 6/46: c_3009635_nw_14_2_20060614.tif
# Generating URL ...
# ...
# Please wait ...
# ...
